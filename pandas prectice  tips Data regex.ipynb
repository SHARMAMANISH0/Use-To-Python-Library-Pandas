# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\BHARAMAN\\Downloads\\tips - tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()  # top 5 data
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.iloc[:4,:3]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male

# %%
# df.loc[1:3,['tip','sex']]

# %%
df.loc[1:3,['total_bill','tip']]
# Out:
#    total_bill   tip
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=244, step=1),
#  Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')]

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.size
# Out:
# 1708

# %%
df.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
# df.copy()

# %%
df.sort_values(by = 'day')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2
# 95        40.17  4.73    Male    Yes   Fri  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 132       11.17  1.50  Female     No  Thur   Lunch     2
# 131       20.27  2.83  Female     No  Thur   Lunch     2
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.sort_index()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
 df['total_bill'].astype(int)
# Out:
# 0      16
# 1      10
# 2      21
# 3      23
# 4      24
#        ..
# 239    29
# 240    27
# 241    22
# 242    17
# 243    18
# Name: total_bill, Length: 244, dtype: int32

# %%
# t = df.add(4)
# t
df['total_bill']= df['total_bill'].add(4)

df['total_bill']
# Out:
# 0      32
# 1      26
# 2      37
# 3      39
# 4      40
#        ..
# 239    45
# 240    43
# 241    38
# 242    33
# 243    34
# Name: total_bill, Length: 244, dtype: int32

# %%
df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
df.max()
# Out:
# total_bill       66
# tip            10.0
# sex            Male
# smoker          Yes
# day            Thur
# time          Lunch
# size              6
# dtype: object

# %%
df.min()
# Out:
# total_bill        19
# tip              1.0
# sex           Female
# smoker            No
# day              Fri
# time          Dinner
# size               1
# dtype: object

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ValueError: could not convert string to float: '...'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:786, in nanmedian(values, axis, skipna, mask)
#     785 try:
# --> 786     values = values.astype("f8")
#     787 except ValueError as err:
#     788     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.median()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11623, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, numeric_only, **kwargs)
#   11606 @doc(
#   11607     _num_doc,
#   11608     desc="Return the median of the values over the requested axis.",
#    (...)
#   11621     **kwargs,
# ...

# %%
df.sum()
# Out:
# total_bill                                                 8618
# tip                                                      731.58
# sex           FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# smoker        NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# day           SunSunSunSunSunSunSunSunSunSunSunSunSunSunSunS...
# time          DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...
# size                                                        627
# dtype: object

# %%
df.filter(items = ['total_bill','tip'])
# Out:
#      total_bill   tip
# 0            32  1.01
# 1            26  1.66
# 2            37  3.50
# 3            39  3.31
# 4            40  3.61
# ..          ...   ...
# 239          45  5.92
# 240          43  2.00
# 241          38  2.00
# 242          33  1.75
# 243          34  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill' , 'tip']]
# Out:
#      total_bill   tip
# 0            32  1.01
# 1            26  1.66
# 2            37  3.50
# 3            39  3.31
# 4            40  3.61
# ..          ...   ...
# 239          45  5.92
# 240          43  2.00
# 241          38  2.00
# 242          33  1.75
# 243          34  3.00
#
# [244 rows x 2 columns]

# %%
df.filter(items = [3,4], axis =0 )  ## axis = 0 means row wise  operation
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 3          39  3.31    Male     No  Sun  Dinner     2
# 4          40  3.61  Female     No  Sun  Dinner     4

# %%
t = df.filter(like = '5' , axis = 0)
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 5            41  4.71    Male     No   Sun  Dinner     4
# 15           37  3.92    Male     No   Sun  Dinner     2
# 25           33  2.34    Male     No   Sat  Dinner     4
# 35           40  3.60    Male     No   Sat  Dinner     3
# 45           34  3.00    Male     No   Sun  Dinner     2
# 50           28  2.50    Male     No   Sun  Dinner     2
# 51           26  2.60  Female     No   Sun  Dinner     2
# 52           50  5.20  Female     No   Sun  Dinner     4
# 53           25  1.56    Male     No   Sun  Dinner     2
# 54           41  4.34    Male     No   Sun  Dinner     4
# 55           35  3.51    Male     No   Sun  Dinner     2
# 56           54  3.00    Male    Yes   Sat  Dinner     4
# 57           42  1.50  Female     No   Sat  Dinner     2
# 58           27  1.76    Male    Yes   Sat  Dinner     2
# 59           64  6.73    Male     No   Sat  Dinner     4
# ...

# %%
df.to_dict()
# Out:
# {'total_bill': {0: 32,
#   1: 26,
#   2: 37,
#   3: 39,
#   4: 40,
#   5: 41,
#   6: 24,
#   7: 42,
#   8: 31,
#   9: 30,
#   10: 26,
#   11: 51,
#   12: 31,
#   13: 34,
#   14: 30,
#   15: 37,
#   16: 26,
#   17: 32,
#   18: 32,
#   19: 36,
#   20: 33,
#   21: 36,
#   22: 31,
#   23: 55,
#   24: 35,
#   25: 33,
#   26: 29,
#   27: 28,
#   28: 37,
#   29: 35,
#   30: 25,
#   31: 34,
#   32: 31,
#   33: 36,
#   34: 33,
#   35: 40,
#   36: 32,
#   37: 32,
#   38: 34,
#   39: 47,
#   40: 32,
#   41: 33,
#   42: 29,
#   43: 25,
#   44: 46,
#   45: 34,
#   46: 38,
#   47: 48,
#   48: 44,
#   49: 34,
#   50: 28,
#   51: 26,
#   52: 50,
#   53: 25,
#   54: 41,
#   55: 35,
#   56: 54,
#   57: 42,
#   58: 27,
#   59: 64,
#   60: 36,
#   61: 29,
#   62: 27,
#   63: 34,
#   64: 33,
#   65: 36,
#   66: 32,
#   67: 19,
#   68: 36,
#   69: 31,
#   70: 28,
#   71: 33,
#   72: 42,
#   73: 41,
#   74: 30,
#   75: 26,
#   76: 33,
#   77: 43,
#   78: 38,
#   79: 33,
#   80: 35,
#   81: 32,
#   82: 26,
# ...

# %%
df.to_string()
# Out:
# '     total_bill    tip     sex smoker   day    time  size\n0            32   1.01  Female     No   Sun  Dinner     2\n1            26   1.66    Male     No   Sun  Dinner     3\n2            37   3.50    Male     No   Sun  Dinner     3\n3            39   3.31    Male     No   Sun  Dinner     2\n4            40   3.61  Female     No   Sun  Dinner     4\n5            41   4.71    Male     No   Sun  Dinner     4\n6            24   2.00    Male     No   Sun  Dinner     2\n7            42   3.12    Male     No   Sun  Dinner     4\n8            31   1.96    Male     No   Sun  Dinner     2\n9            30   3.23    Male     No   Sun  Dinner     2\n10           26   1.71    Male     No   Sun  Dinner     2\n11           51   5.00  Female     No   Sun  Dinner     4\n12           31   1.57    Male     No   Sun  Dinner     2\n13           34   3.00    Male     No   Sun  Dinner     4\n14           30   3.02  Female     No   Sun  Dinner     2\n15           37   3.92    Male     No   Sun  Dinner  
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.columns[3]
# Out:
# 'smoker'

# %%
df.columns.tolist()
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
df.columns.values
# Out:
# array(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'],
#       dtype=object)

# %%
# rename columns

df.rename(columns ={
         'total_bill':'phone_bill',
    'tip':'tip_1'
})
# Out:
#      phone_bill  tip_1     sex smoker   day    time  size
# 0            32   1.01  Female     No   Sun  Dinner     2
# 1            26   1.66    Male     No   Sun  Dinner     3
# 2            37   3.50    Male     No   Sun  Dinner     3
# 3            39   3.31    Male     No   Sun  Dinner     2
# 4            40   3.61  Female     No   Sun  Dinner     4
# ..          ...    ...     ...    ...   ...     ...   ...
# 239          45   5.92    Male     No   Sat  Dinner     3
# 240          43   2.00  Female    Yes   Sat  Dinner     2
# 241          38   2.00    Male    Yes   Sat  Dinner     2
# 242          33   1.75    Male     No   Sat  Dinner     2
# 243          34   3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill'] = df['total_bill'].where(df['total_bill']>10,other= 0)
df.head(100)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0            0  1.01  Female     No  Sun  Dinner     2
# 1            0  1.66    Male     No  Sun  Dinner     3
# 2            0  3.50    Male     No  Sun  Dinner     3
# 3            0  3.31    Male     No  Sun  Dinner     2
# 4            0  3.61  Female     No  Sun  Dinner     4
# ..         ...   ...     ...    ...  ...     ...   ...
# 95          56  4.73    Male    Yes  Fri  Dinner     4
# 96          43  4.00    Male    Yes  Fri  Dinner     2
# 97           0  1.50    Male    Yes  Fri  Dinner     2
# 98           0  3.00    Male    Yes  Fri  Dinner     2
# 99           0  1.50    Male     No  Fri  Dinner     2
#
# [100 rows x 7 columns]
